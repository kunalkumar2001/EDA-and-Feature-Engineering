# %%
# !pip install klib
# Out:
# Collecting klib
#   Downloading klib-1.4.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: jinja2>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from klib) (3.1.6)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from klib) (3.10.0)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from klib) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from klib) (2.2.2)
# Requirement already satisfied: plotly>=5.24.0 in /usr/local/lib/python3.12/dist-packages (from klib) (5.24.1)
# Requirement already satisfied: scipy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from klib) (1.16.3)
# Collecting screeninfo>=0.8.1 (from klib)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: seaborn>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from klib) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.0->klib) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->klib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.4->klib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.4->klib) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.24.0->klib) (9.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->klib) (1.17.0)
# Downloading klib-1.4.0-py3-none-any.whl (23 kB)
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Installing collected packages: screeninfo, klib
# Successfully installed klib-1.4.0 screeninfo-0.8.1

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import klib
import pandas as pd

# %%
# klib.describe - functions for visualizing datasets
# - klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# - klib.corr_mat(df) # returns a color-encoded correlation matrix
# - klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# - klib.corr_interactive_plot(df, split="neg").show() # returns an interactive correlation plot using plotly
# - klib.dist_plot(df) # returns a distribution plot for every numeric feature
# - klib.missingval_plot(df) # returns a figure containing information about missing values

# %%
klib.cat_plot(df)
# Out:
# /usr/local/lib/python3.12/dist-packages/klib/describe.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   data.loc[data[col].isin(value_counts_idx_top), col] = 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2222831409.py in <cell line: 0>()
# ----> 1 klib.cat_plot(df)
#
# /usr/local/lib/python3.12/dist-packages/klib/describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     125         data[col] = data[col].rolling(2, min_periods=1).mean()
#     126
# --> 127         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     128         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     129         sum_top = sum(value_counts_top)
#
# TypeError: 'bool' object is not subscriptable

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_31954_row0_col0, #T_31954_row0_col4, #T_31954_row0_col5, #T_31954_row1_col1, #T_31954_row1_col3, #T_31954_row1_col4, #T_31954_row1_col6, #T_31954_row1_col7, #T_31954_row2_col2, #T_31954_row2_col5, #T_31954_row2_col6, #T_31954_row2_col7, #T_31954_row3_col1, #T_31954_row3_col3, #T_31954_row3_col4, #T_31954_row3_col5, #T_31954_row4_col0, #T_31954_row4_col1, #T_31954_row4_col3, #T_31954_row4_col4, #T_31954_row4_col5, #T_31954_row5_col0, #T_31954_row5_col2, #T_31954_row5_col3, #T_31954_row5_col4, #T_31954_row5_col5, #T_31954_row6_col1, #T_31954_row6_col2, #T_31954_row6_col6, #T_31954_row6_col7, #T_31954_row7_col1, #T_31954_row7_col2, #T_31954_row7_col6, #T_31954_row7_col7 {
#   color: None;
# }
# #T_31954_row0_col1, #T_31954_row0_col2, #T_31954_row0_col3, #T_31954_row0_col6, #T_31954_row0_col7, #T_31954_row1_col0, #T_31954_row1_col2, #T_31954_row1_col5, #T_31954_row2_col0, #T_31954_row2_col1, #T_31954_row2_col3, #T_31954_row2_col4, #T_31954_row3_col0, #T_31954_row3_col2, #T_31954_row3_col6, #T_31954_row3_col7, #T_31954_row4_col2, #T_31954_row4_col6, #T_31954_row4_col7, #T_31954_row5_col1, #T_31954_row5_col6, #T_31954_row5_col7, #T_31954_row6_col0, #T_31954_row6_col3, #T_31954_row6_col4, #T_31954_row6_col5, #T_31954_row7_col0, #T_31954_row7_col3, #T_31954_row7_col4, #T_31954_row7_col5 {
#   color: #FF3344;
# }
# </style>
# <table id="T_31954" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_
>-0.27</td>
#     </tr>
#     <tr>
#       <th id="T_31954_level0_row6" class="row_heading level0 row6" >adult_male</th>
#       <td id="T_31954_row6_col0" class="data row6 col0" >-0.56</td>
#       <td id="T_31954_row6_col1" class="data row6 col1" >0.09</td>
#       <td id="T_31954_row6_col2" class="data row6 col2" >0.28</td>
#       <td id="T_31954_row6_col3" class="data row6 col3" >-0.25</td>
#       <td id="T_31954_row6_col4" class="data row6 col4" >-0.35</td>
#       <td id="T_31954_row6_col5" class="data row6 col5" >-0.18</td>
#       <td id="T_31954_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_31954_row6_col7" class="data row6 col7" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_31954_level0_row7" class="row_heading level0 row7" >alone</th>
#       <td id="T_31954_row7_col0" class="data row7 col0" >-0.20</td>
#       <td id="T_31954_row7_col1" class="data row7 col1" >0.14</td>
#       <td id="T_31954_row7_col2" class="data row7 col2" >0.20</td>
#       <td id="T_31954_row7_col3" class="data row7 col3" >-0.58</td>
#       <td id="T_31954_row7_col4" class="data row7 col4" >-0.58</td>
#       <td id="T_31954_row7_col5" class="data row7 col5" >-0.27</td>
#       <td id="T_31954_row7_col6" class="data row7 col6" >0.40</td>
#       <td id="T_31954_row7_col7" class="data row7 col7" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
klib.corr_plot(df)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_interactive_plot(df, split="neg").show()
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ab0ce94f-c210-4bc7-a89d-7e6adaa861dc" class="plotly-graph-div" style="height:1056px; width:1152px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab0ce94f-c210-4bc7-a89d-7e6adaa861dc")) {                    Plotly.newPlot(                        "ab0ce94f-c210-4bc7-a89d-7e6adaa861dc",                        [{"colorscale":[[0.0,"rgb(84,48,5)"],[0.1,"rgb(140,81,10)"],[0.2,"rgb(191,129,45)"],[0.3,"rgb(223,194,125)"],[0.4,"rgb(246,232,195)"],[0.5,"rgb(245,245,245)"],[0.6,"rgb(199,234,229)"],[0.7,"rgb(128,205,193)"],[0.8,"rgb(53,151,143)"],[0.9,"rgb(1,102,94)"],[1.0,"rgb(0,60,48)"]],"hoverongaps":false,"text":[["","",-0.27,-0.58,-0.58,"","",-0.2],["","",-0.18,-0.35,-0.25,"","",-0.56],["","","","","","",-0.55,""],["","","","","",-0.19,"",""],["","","","","",-0.31,"",-0.04],["","","","","","",-0.37,-0.08],["","","","","","","",-0.34],["","","","","","","",""]],"textfont":{"size":12},"texttemplate":"%{text}","x":["alone","adult_male","fare","parch","sibsp","age","pclass","survived"],"xgap":1,"y":["alone","adult_male","fare","parch","sibsp","age","pclass","survived"],"ygap":1,"z":[[null,null,-0.27183235810610834,-0.5833976837814463,-0.5844711694024876,null,null,-0.2033670856998918],[null,null,-0.18202373008059775,-0.3499427513001228,-0.25358568216181265,null,null,-0.5570800422053257],[null,null,null,null,null,null,-0.5494996199439076,null],[null,null,null,null,null,-0.18911926263203524,null,null],[null,null,null,null,null,-0.30824675892365677,null,-0.03532249888573556],[null,null,null,null,null,null,-0.36922601531551735,-0.07722109457217759],[null,null,null,null,null,null,null,-0.3384810359610152],[null,null,null,null,null,null,null,null]],"zmax":0.53,"zmin":-0.53,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
klib.dist_plot(df)
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
#  klib.clean - functions for cleaning datasets
# - klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# - klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
# - klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
# - klib.drop_missing(df) # drops missing values, also called in data_cleaning()
# - klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
# - klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.mv_col_handling(df)
# Out:
# /usr/local/lib/python3.12/dist-packages/klib/clean.py:459: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /usr/local/lib/python3.12/dist-packages/klib/clean.py:459: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# 1    woman       False    Cherbourg   yes  False
# 2    woman       False  Southampton   yes   True
# 3    woman       False  Southampton   yes  False
# 4      man        True  Southampton    no   True
# ..     ...         ...          ...   ...    ...
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
klib.drop_missing(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.convert_datatypes(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch       fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.250000        S   Third
# 1           1       1  female  38.0      1      0  71.283302        C   First
# 2           1       3  female  26.0      0      0   7.925000        S   Third
# 3           1       1  female  35.0      1      0  53.099998        S   First
# 4           0       3    male  35.0      0      0   8.050000        S   Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...     ...
# 886         0       2    male  27.0      0      0  13.000000        S  Second
# 887         1       1  female  19.0      0      0  30.000000        S   First
# 888         0       3  female   NaN      1      2  23.450001        S   Third
# 889         1       1    male  26.0      0      0  30.000000        C   First
# 890         0       3    male  32.0      0      0   7.750000        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15) - Remaining NAs: 692
#
#
# Dropped rows: 107
#      of which 107 duplicates. (Rows (first 150 shown): [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)
#      survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.250000        S  Third
# 1           1       1  female  38.0      1      0  71.283302        C  First
# 2           1       3  female  26.0      0      0   7.925000        S  Third
# 3           1       1  female  35.0      1      0  53.099998        S  First
# 4           0       3    male  35.0      0      0   8.050000        S  Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...    ...
# 779         0       3  female  39.0      0      5  29.125000        Q  Third
# 780         1       1  female  19.0      0      0  30.000000        S  First
# 781         0       3  female   NaN      1      2  23.450001        S  Third
# 782         1       1    male  26.0      0      0  30.000000        C  First
# 783         0       3    male  32.0      0      0   7.750000        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 779  woman       False  NaN   Queenstown    no  False
# 780  woman       False    B  Southampton   yes   True
# 781  woman       False  NaN  Southampton    no  False
# 782    man        True    C    Cherbourg   yes   True
# 783    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
klib.clean_column_names(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.pool_duplicate_subsets(df)
# Out:
#       age  pooled_vars
# 0    22.0            0
# 1    38.0            1
# 2    26.0            2
# 3    35.0            3
# 4    35.0            4
# ..    ...          ...
# 886  27.0          134
# 887  19.0          887
# 888   NaN          888
# 889  26.0          889
# 890  32.0          116
#
# [891 rows x 2 columns]
